# %% [markdown]
# # Abalone Case Study

# %% [markdown]
# # Problem Statement

# %% [markdown]
# The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict the age. Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.

# %% [markdown]
# # Attribute Information

# %% [markdown]
# Given is the attribute name, attribute type, the measurement unit and a brief description. The number of rings is the value to predict.
#
# Name / Data Type / Measurement Unit / Description
# -----------------------------
# Sex / nominal / -- / M, F, and I (infant)
#
# Length / continuous / mm / Longest shell measurement
#
# Diameter / continuous / mm / perpendicular to length
#
# Height / continuous / mm / with meat in shell
#
# Whole weight / continuous / grams / whole abalone
#
# Shucked weight / continuous / grams / weight of meat
#
# Viscera weight / continuous / grams / gut weight (after bleeding)
#
# Shell weight / continuous / grams / after being dried
#
# Rings / integer / -- / +1.5 gives the age in years.
#
# Predict the rings of each abalone which will lead to the age of that abalone.

# %%
import pandas as pd

# %%
abalone=pd.read_csv('Abalone case study.csv')
abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
abalone.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# # About the Columns:

# %% [markdown]
# 1.Sex: Gender of the species, either M/F.
#
# 2.length: The measurement or extent of something from end to end.
#
# 3.Diameter: A straight line that runs from one side of a figure and passes through the center Measure the diameter of the circle.
#
# 4.Height: The measurement of someone or something from head to foot or from base to top.
#
# 5.Whole weight: The weight of a person or thing is how heavy they are, measured in units such as kilograms, pounds, or tons.
#
# 6.Shucked weight: Shucked weight is supposed to be the weight without the shell.
#
# 7.Viscera weight: Visceral fat is fat that wraps around your abdominal organs deep inside your body.
#
# 8.Shell weight: Shell weight means that it's primarily a windproof, possibly waterproof shell that is intended to be worn over warmer clothes in cold weather, or by itself in warmer climates.
#
# 9.Rings: a small circular band, typically of precious metal and often set with one or more gemstones, worn on a finger as an ornament or a token of marriage, engagement, or authority.

# %% [markdown]
# Using problem statement, converting rings to Age.

# %%
abalone['Rings']=abalone['Rings']+1.5

# %% [markdown]
# Changing name of column 'Rings' to 'Age'.

# %%
abalone=abalone.rename(columns={'Rings':'Age'},inplace=False)

# %%
abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
abalone.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Age               0
# dtype: int64

# %%
abalone.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Age               float64
# dtype: object

# %% [markdown]
# # Changing object to int values using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lencode=LabelEncoder()
abalone['Sex']=lencode.fit_transform(abalone['Sex'])
abalone
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
abalone.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight          Age
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831    11.433684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %%
abalone['Age'].value_counts()
# Out:
# 10.5    689
# 11.5    634
# 9.5     568
# 12.5    487
# 8.5     391
# 13.5    267
# 7.5     259
# 14.5    203
# 15.5    126
# 6.5     115
# 16.5    103
# 17.5     67
# 18.5     58
# 5.5      57
# 19.5     42
# 20.5     32
# 21.5     26
# 4.5      15
# 22.5     14
# 24.5      9
# 23.5      6
# 28.5      2
# 25.5      2
# 3.5       1
# 26.5      1
# 27.5      1
# 30.5      1
# 2.5       1
# Name: Age, dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# Using distplot and scatter plot let's see how data is distributed and analyze the relationship.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(20,25),facecolor='w')
plotnumber=1
for column in abalone:
    if plotnumber<=16:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(abalone[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Here we can see building blocks are properly distributed within the normalised curve.

# %% [markdown]
# # Correlation:

# %%
abalone.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Age            -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight       Age
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(abalone.corr(),annot=True,linewidth=0.5,linecolor='white',fmt='.2f')
plt.show()

# %% [markdown]
# # Outcome of Correlation:

# %% [markdown]
# All the columns are positively correlated with the target column.
#
# Length, Diameter, Height, Whole weight, Shell weight has 56, 57, 56, 54, 63 percent correlation with the target column which can be considered as strong bond. Shucked weight and Viscera weight has 42 and 50 percent correlation with target column, which can also be considered as strong bond. Sex has negative correlation with target column but is in the range and won't affect the target column.
#
# Max correlation: Shell weight
#
# Min correlation: Sex

# %% [markdown]
# # Describing datasets with Heatmap:

# %%
abalone.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight          Age
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831    11.433684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(abalone.describe().transpose(),annot=True,fmt='.2f',linewidth=0.1,cmap='Blues',linecolor='black')
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
plt.title('Variable Summary',fontsize=20)
plt.show()

# %% [markdown]
# # Outcome of describe of datasets:

# %% [markdown]
# From above we are determining mean, standard deviation, min. and max. value of each column, which will furthur help us in data cleaning.

# %% [markdown]
# Total number of rows and columns in dataset:
#
#     1.4177 rows
#
#     2.9 columns

# %% [markdown]
# Sex:
#
#     1.Mean=1.05
#     2.std=0.82
#     3.max_value=2.00
#     4.min_value=0.00
#
# Length:
#
#     1.Mean=0.52
#     2.std=0.12
#     3.max_value=0.81
#     4.min_value=0.07
#
# Diameter:
#
#     1.Mean=0.41
#     2.std=0.10
#     3.max_value=0.65
#     4.min_value=0.06
#
# Height:
#
#     1.Mean=0.14
#     2.std=0.04
#     3.max_value=1.13
#     4.min_value=0.00
#
# Whole weight:
#
#     1.Mean=0.83
#     2.std=0.49
#     3.max_value=2.83
#     4.min_value=0.00
#
# Shucked weight:
#
#     1.Mean=0.36
#     2.std=0.22
#     3.max_value=1.49
#     4.min_value=0.00
#
# Viscera weight:
#
#     1.Mean=0.18
#     2.std=0.11
#     3.max_value=0.76
#     4.min_value=0.00
#
# Shell weight:
#
#     1.Mean=0.24
#     2.std=0.14
#     3.max_value=1.00
#     4.min_value=0.00
#
# Age:
#
#     1.Mean=11.43
#     2.std=3.22
#     3.max_value=2.50
#     4.min_value=30.50
#
# Age is our target column.

# %% [markdown]
# # Using subplot and distplot to check data are normalised or not, considering mean values.

# %%
import itertools

cols=['Sex',
     'Length',
     'Diameter',
     'Height',
     'Whole weight',
     'Shucked weight',
     'Viscera weight',
     'Shell weight',
     ]
length=len(cols)
cs=['b','r','g','c','m','k','lime','g']
fig=plt.figure(figsize=(15,25))
for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(5,2,j+1)
    ax=sns.distplot(abalone[i],color=k,rug=True)
    ax.set_facecolor('w')
    plt.axvline(abalone[i].mean(),linestyle='--',label='mean',color='k')
    plt.legend(loc='best')
    plt.title(i,color='navy')
    plt.xlabel('')

# %% [markdown]
# # Observation:

# %% [markdown]
# From above we can see that data is not normalised for some features and we should proceed with the data cleaning.

# %%
abalone.hist(edgecolor='red',linewidth=1.5,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Sex'}>,
#         <AxesSubplot:title={'center':'Length'}>,
#         <AxesSubplot:title={'center':'Diameter'}>],
#        [<AxesSubplot:title={'center':'Height'}>,
#         <AxesSubplot:title={'center':'Whole weight'}>,
#         <AxesSubplot:title={'center':'Shucked weight'}>],
#        [<AxesSubplot:title={'center':'Viscera weight'}>,
#         <AxesSubplot:title={'center':'Shell weight'}>,
#         <AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
plt.figure(figsize=(10,6))
abalone.corr()['Age'].sort_values(ascending=False).drop(['Age']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Correlation with the target column',fontsize=14)
plt.title('Correlation features with the target column',fontsize=14)
plt.show()

# %% [markdown]
# None of the feature is having negative correlation except Sex.

# %%
abalone.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Age               0
# dtype: int64

# %% [markdown]
# None of the column is having NaN or NaT value.

# %%
abalone.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Age               1.114102
# dtype: float64

# %% [markdown]
# # Skewness:

# %% [markdown]
# We are taking Skewness threshold as +/-0.5. From the following observation, the columns falls under high skewness:
#
#     length, skewness=-0.639873, Diameter, skewness=-0.609198, Height, skewness=3.128817, Shucked weight, skewness=0.719098, Shell weight, skewness=0.620927

# %%
abalone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   int32
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Age             4177 non-null   float64
# dtypes: float64(8), int32(1)
# memory usage: 277.5 KB

# %% [markdown]
# From above we can have columns datatype and memory used by the dataframe.

# %% [markdown]
# # Outliers checking:

# %% [markdown]
# to check outliers we are using box plot.

# %%
abalone.plot(kind='box',subplots=True,layout=(3,3),figsize=(16,20),color='Teal')
plt.xticks(fontsize=16)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# From above we can see that columns ['length','Diameter','Whole weight','Shucked weight','Viscera weight','Shell weight'] has more outliers, while column 'Height' has less outliers, while our target column does not come under outlier checking.

# %% [markdown]
# # Removing outliers:

# %% [markdown]
# Checking the percentage of data falling under outliers.

# %%
from scipy.stats import zscore
import numpy as np

# %%
z=np.abs(zscore(abalone))
z.shape
# Out:
# (4177, 9)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
# ...

# %%
abalone_new=abalone[(z<3).all(axis=1)]
print(abalone.shape)
print(abalone_new.shape)
# Out:
# (4177, 9)
# (4027, 9)

# %% [markdown]
# # Percentage Data loss

# %%
loss_percent=(4177-4027)/4177*100
print(loss_percent)
# Out:
# 3.5910940866650707

# %% [markdown]
# Percentage loss is not more than 5 percent.
#
# We will once try for IQR.

# %%
Q1=abalone.quantile(0.25)
Q3=abalone.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Sex               2.0000
# Length            0.1650
# Diameter          0.1300
# Height            0.0500
# Whole weight      0.7115
# Shucked weight    0.3160
# Viscera weight    0.1595
# Shell weight      0.1990
# Age               3.0000
# dtype: float64

# %%
abalone_new1=abalone[-((abalone<(Q1-1.5*IQR)) | (abalone>(Q3+1.5*IQR))).any(axis=1)]
print(abalone_new1.shape)
# Out:
# (3781, 9)

# %%
percentage_loss=(4177-3781)/4177*100
print(percentage_loss)
# Out:
# 9.480488388795786

# %% [markdown]
# Since the percentage loss in zscore is less as compared to IQR, so we will go with zscore over IQR.

# %% [markdown]
# # Dividing data in features and vectors:

# %%
x=abalone_new.drop(columns=['Age'])
y=abalone_new['Age']

# %%
x.dtypes
# Out:
# Sex                 int32
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# dtype: object

# %% [markdown]
# Observing relationship between features and target vectors.

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in x:
    if plotnumber<=16:
        ax=plt.subplot(3,3,plotnumber)
        sns.scatterplot(y,x[column])
        plt.xlabel('Age',fontsize=20)
        plt.ylabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Transforming data to remove skewness:

# %%
abalone.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Age               1.114102
# dtype: float64

# %% [markdown]
# Outcome of skewness, normal skewed data is between +/-0.5
#
# Column which are not under the normal skewness range:
#
#     Sex
#     Length
#     Diameter
#     Height
#     Shucked weight
#     Shell weight

# %% [markdown]
# Using power_transform to remove skewness.

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 1.13432919, -0.68445079, -0.54337947, ..., -0.54086524,
#         -0.68803217, -0.58635376],
#        [ 1.13432919, -1.4117394 , -1.40113174, ..., -1.31131805,
#         -1.33285416, -1.33271691],
#        [-1.31306782, -0.0462191 ,  0.03716259, ..., -0.36270513,
#         -0.24037305, -0.08021413],
#        ...,
#        [ 1.13432919,  0.65112915,  0.70592133, ...,  0.90189694,
#          1.08965131,  0.66363183],
#        [-1.31306782,  0.92606411,  0.8377131 , ...,  0.92415296,
#          0.87642835,  0.57752029],
#        [ 1.13432919,  1.9719402 ,  1.85550496, ...,  2.31446634,
#          1.73214622,  1.85675543]])

# %% [markdown]
# Applying Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_t=sc.fit_transform(x)
x_t
# Out:
# array([[ 1.13432919, -0.68445079, -0.54337947, ..., -0.54086524,
#         -0.68803217, -0.58635376],
#        [ 1.13432919, -1.4117394 , -1.40113174, ..., -1.31131805,
#         -1.33285416, -1.33271691],
#        [-1.31306782, -0.0462191 ,  0.03716259, ..., -0.36270513,
#         -0.24037305, -0.08021413],
#        ...,
#        [ 1.13432919,  0.65112915,  0.70592133, ...,  0.90189694,
#          1.08965131,  0.66363183],
#        [-1.31306782,  0.92606411,  0.8377131 , ...,  0.92415296,
#          0.87642835,  0.57752029],
#        [ 1.13432919,  1.9719402 ,  1.85550496, ...,  2.31446634,
#          1.73214622,  1.85675543]])

# %%
y.value_counts()
# Out:
# 10.5    686
# 11.5    625
# 9.5     566
# 12.5    472
# 8.5     391
# 7.5     258
# 13.5    251
# 14.5    199
# 15.5    119
# 6.5     113
# 16.5    102
# 17.5     62
# 18.5     53
# 5.5      49
# 19.5     39
# 20.5     32
# 4.5      10
# Name: Age, dtype: int64

# %%
print(x_t.shape)
print(y.shape)
# Out:
# (4027, 8)
# (4027,)

# %% [markdown]
# # Regressor Model Building:

# %% [markdown]
# # Linear Regression:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lr=LinearRegression()
max_scr=0
for i in range(0,10000):
    x_train,x_test,y_train,y_test=train_test_split(x_t,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print('At random state',i,'The model performs well')
        print('At random state:-',i)
        print('Training score is:-',r2_score(y_train,pred_train)*100)
        print('Testing score is:-',r2_score(y_test,pred_test)*100)
# Out:
# At random state 288 The model performs well
# At random state:- 288
# Training score is:- 51.23721722558812
# Testing score is:- 51.24287785376572
# At random state 612 The model performs well
# At random state:- 612
# Training score is:- 51.245317940365396
# Testing score is:- 51.246191530852684
# At random state 862 The model performs well
# At random state:- 862
# Training score is:- 51.18255736180264
# Testing score is:- 51.18383375883832
# At random state 1367 The model performs well
# At random state:- 1367
# Training score is:- 51.2139120448712
# Testing score is:- 51.21116544731377
# At random state 1493 The model performs well
# At random state:- 1493
# Training score is:- 51.23042359224146
# Testing score is:- 51.22896358655675
# At random state 3239 The model performs well
# At random state:- 3239
# Training score is:- 51.23496676489769
# Testing score is:- 51.229409639060684
# At random state 3580 The model performs well
# At random state:- 3580
# ...

# %%
x_train_b,x_test_b,y_train_b,y_test_b=train_test_split(x_t,y,random_state=9884,test_size=0.20)

# %% [markdown]
# We are using random state 9884, as at random state 9884, it is giving highest accuracy.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Regularization

# %% [markdown]
# # 1.Lasso:

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
grid_search=GridSearchCV(ls,parameters)
grid_search.fit(x_train,y_train)
print(grid_search.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train_b,y_train_b)
ls.score(x_train_b,y_train_b)
pred_ls=ls.predict(x_test_b)

lss=r2_score(y_test_b,pred_ls)
for i in range(2,10):
    lsscore=cross_val_score(ls,x_t,y,cv=j)
    lsc=lsscore.mean()
    print('At cv:-',i)
    print('cross validation score is:-',lsc*100)
    print('r2_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 2
# cross validation score is:- 44.429833872749484
# r2_score is:- 51.252214379934394
#
#
# At cv:- 3
# cross validation score is:- 44.429833872749484
# r2_score is:- 51.252214379934394
#
#
# At cv:- 4
# cross validation score is:- 44.429833872749484
# r2_score is:- 51.252214379934394
#
#
# At cv:- 5
# cross validation score is:- 44.429833872749484
# r2_score is:- 51.252214379934394
#
#
# At cv:- 6
# cross validation score is:- 44.429833872749484
# r2_score is:- 51.252214379934394
#
#
# At cv:- 7
# cross validation score is:- 44.429833872749484
# r2_score is:- 51.252214379934394
#
#
# At cv:- 8
# cross validation score is:- 44.429833872749484
# r2_score is:- 51.252214379934394
#
#
# At cv:- 9
# cross validation score is:- 44.429833872749484
# r2_score is:- 51.252214379934394

# %%
print('At cv:-',3)
print('cross validation score is:-',44.429)
print('r2_score is:-',51.2522)
# Out:
# At cv:- 3
# cross validation score is:- 44.429
# r2_score is:- 51.2522

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_ls))
print('mean squared error:',mean_squared_error(y_test_b,pred_ls))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_ls)))
# Out:
# Error
# mean absolute error: 1.5217951594617802
# mean squared error: 4.0538808778969
# root mean squared error: 2.013425160739008

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_ls,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual age',fontsize=14)
plt.ylabel('predicted age',fontsize=14)
plt.title('Lasso Regression',fontsize=14)
plt.show()

# %% [markdown]
# # 2.Ridge:

# %%
from sklearn.linear_model import Ridge
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'fit_intercept':[True,False],'normalize':[True,False],'copy_X':[True,False],'tol':[0.001,0.01,0.1],'random_state':list(range(0,10))}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train_b,y_train_b)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'normalize': False, 'random_state': 0, 'tol': 0.001}

# %%
rd=Ridge(alpha=1,copy_X=True,fit_intercept=True,normalize=False,random_state=0,tol=0.001)
rd.fit(x_train_b,y_train_b)
pred_rd=rd.predict(x_test_b)
rds=r2_score(y_test_b,pred_rd)
print('r2 score is:',rds*100)
rdscore=cross_val_score(rd,x_t,y,cv=3)
rdc=rdscore.mean()
print('cross validation score is:',rdc*100)
# Out:
# r2 score is: 51.25518284076445
# cross validation score is: 49.73100437834636

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_rd))
print('mean squared error:',mean_squared_error(y_test_b,pred_rd))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_rd)))
# Out:
# Error
# mean absolute error: 1.5218237293343215
# mean squared error: 4.053634019779293
# root mean squared error: 2.0133638567778287

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_rd,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual age',fontsize=14)
plt.ylabel('predicted age',fontsize=14)
plt.title('Ridge Regression',fontsize=14)
plt.show()

# %% [markdown]
# # Ensemble Techniques:

# %%
from sklearn.tree import DecisionTreeRegressor
parameters={'criterion':['mse','friedman_mse','mae'],'splitter':['best','random']}
dtr=DecisionTreeRegressor()
clf=GridSearchCV(dtr,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'splitter': 'best'}

# %%
dtr=DecisionTreeRegressor(criterion='mse',splitter='best')
dtr.fit(x_train_b,y_train_b)
dtr.score(x_train_b,y_train_b)
pred_dtr=dtr.predict(x_test_b)
dts=r2_score(y_test_b,pred_dtr)
print('r2_score is:',dts*100)

dtscore=cross_val_score(dtr,x_t,y,cv=3)
dtc=dtscore.mean()
print('cross validation score is:',dtc*100)
# Out:
# r2_score is: 10.484113243890247
# cross validation score is: 3.6132315989581665

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_dtr))
print('mean squared error:',mean_squared_error(y_test_b,pred_dtr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_dtr)))
# Out:
# Error
# mean absolute error: 1.9404466501240696
# mean squared error: 7.444168734491315
# root mean squared error: 2.7284003984920018

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_dtr,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual age',fontsize=14)
plt.ylabel('predicted age',fontsize=14)
plt.title('Decision Tree Regressor',fontsize=14)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['friedman_mse','mae'],'n_estimators':[100,200,300]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'n_estimators': 300}

# %%
rf=RandomForestRegressor(criterion='friedman_mse',n_estimators=200)
rf.fit(x_train_b,y_train_b)
rf.score(x_train_b,y_train_b)
pred_rf=rf.predict(x_test_b)
rfs=r2_score(y_test_b,pred_rf)
print('r2_score is:',rfs*100)

rfscore=cross_val_score(rf,x_t,y,cv=3)
rfc=rfscore.mean()
print('cross validation score is:',rfc*100)
# Out:
# r2_score is: 52.61939368998145
# cross validation score is: 52.11225680245225

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_rf))
print('mean squared error:',mean_squared_error(y_test_b,pred_rf))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_rf)))
# Out:
# Error
# mean absolute error: 1.48204094292804
# mean squared error: 3.940185825062035
# root mean squared error: 1.9849901322329124

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_rf,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual age',fontsize=14)
plt.ylabel('predicted age',fontsize=14)
plt.title('Random Forest Regressor',fontsize=14)
plt.show()

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
parameters = {'loss' : ['ls', 'lad', 'huber', 'quantile'],'n_estimators':[50,100,200],'criterion':['friedman_mse', 'mse']}
gbr=GradientBoostingRegressor()
clf = GridSearchCV(gbr,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'loss': 'ls', 'n_estimators': 100}

# %%
gbr=GradientBoostingRegressor(criterion='mse',loss='ls',n_estimators=100)
gbr.fit(x_train_b,y_train_b)
gbr.score(x_train_b,y_train_b)
pred_gbr=gbr.predict(x_test_b)
gbrs=r2_score(y_test_b,pred_gbr)
print('r2_score is:',gbrs*100)

gbrscore=cross_val_score(gbr,x_t,y,cv=3)
gbrc=rfscore.mean()
print('cross validation score is:',gbrc*100)
# Out:
# r2_score is: 54.52372833362071
# cross validation score is: 52.11225680245225

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_gbr))
print('mean squared error:',mean_squared_error(y_test_b,pred_gbr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_gbr)))
# Out:
# Error
# mean absolute error: 1.4519710133924018
# mean squared error: 3.781820769116024
# root mean squared error: 1.9446904044387179

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_gbr,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual age',fontsize=14)
plt.ylabel('predicted age',fontsize=14)
plt.title('Gradient Boost Regressor',fontsize=14)
plt.show()

# %%
from sklearn.svm import SVR

parameters = { 'kernel': ['linear', 'poly','rbf', 'sigmoid'],'gamma':['auto','scale']}
sv = SVR()
clf = GridSearchCV(sv,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'gamma': 'auto', 'kernel': 'rbf'}

# %%
sv = SVR(kernel = 'rbf', gamma = 'auto')
sv.fit(x_train_b, y_train_b)
sv.score(x_train_b, y_train_b)
pred_sv = sv.predict(x_test_b)

svs = r2_score(y_test_b,pred_sv)
print('R2 Score:',svs*100)

svscore = cross_val_score(sv,x_t,y,cv=3)
svc = svscore.mean() 
print('Cross Val Score:',svc*100)
# Out:
# R2 Score: 53.80322098096569
# Cross Val Score: 52.804087059655345

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b, y=pred_sv, color='b')
plt.plot(y_test_b,y_test_b, color='r')
plt.xlabel('Actual compressive strength',fontsize=14)
plt.ylabel('Predicted compressive strength',fontsize=14)
plt.title('Support vector regressor',fontsize=18)
plt.show()

# %% [markdown]
# # The best model is RandomForestRegressor.Since the difference between the percentage score of cross validation and r2_score is optimum.

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename='inhouse_abalone_project.pk4'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(rf.predict(x_test_b))
abalone_com=pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
abalone_com
# Out:
#      original  predicted
# 0        12.5     11.775
# 1        13.5     11.005
# 2         7.5     13.730
# 3         9.5     14.680
# 4        10.5      9.525
# ..        ...        ...
# 801      11.5      9.410
# 802      10.5     11.185
# 803      11.5      7.895
# 804      11.5     13.355
# 805       6.5      7.155
#
# [806 rows x 2 columns]

# %% [markdown]
# # From the above table the model is predicted the values with 50-55 percent accuracy.

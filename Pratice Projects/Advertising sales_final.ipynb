# %% [markdown]
# # Advertising Sales Channel Prediction

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# Sales Channel Prediction Case Study
#
# When a company enters a market, the distribution strategy and channel it uses are keys to its success in the market, as well as market know-how and customer knowledge and understanding. Because an effective distribution strategy under efficient supply-chain management opens doors for attaining competitive advantage and strong brand equity in the market, it is a component of the marketing mix that cannot be ignored .
#
# The distribution strategy and the channel design have to be right the first time. The case study of Sales channel includes the detailed study of TV, radio and newspaper channel. The predict the total sales generated from all the sales channel.

# %%
import pandas as pd

# %%
sales=pd.read_csv('advertising sales.csv')
sales
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
sales.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %% [markdown]
# # About Columns:

# %% [markdown]
# 1.Unnmaed:0 It is the serial number of each row.
#
# 2.TV: Television, A box which shows moving pictures, at 1st it was black and white, now there are color TV's.
#
# 3.Radio: The transmission and reception of electromagnetic waves of radio frequency, especially those carrying sound messages.
#
# 4.Newspaper: A printed paper of certain publication, consisting of folded unstaped sheets and containing news, articles, advertisements and correspondence.
#
# 5.Sales: The exchange of a commodity for money, the action of selling something.

# %% [markdown]
# Here Unnamed: 0 is the serial number column, which we can drop, as it is not affecting our dataset.

# %%
sales.drop(['Unnamed: 0'],axis=1,inplace=True)
sales
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sales.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
sales.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %% [markdown]
# Here all the values are float64, so we can proceed with the EDA.

# %% [markdown]
# # EDA:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(20,25),facecolor='w')
plotnumber=1
for column in sales:
    if plotnumber<=10:
        ax=plt.subplot(2,2,plotnumber)
        sns.distplot(sales[column])
        plt.xlabel(column,fontsize=14)
    plotnumber+=1
plt.tight_layout()

# %%
sns.pairplot(x_vars='TV',y_vars='sales',data=sales,size=6)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
sns.pairplot(x_vars='radio',y_vars='sales',data=sales,size=6)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
sns.pairplot(x_vars='newspaper',y_vars='sales',data=sales,size=6)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # Correlation:

# %%
sales.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(sales.corr(),annot=True,linewidth=0.2,linecolor='white',fmt='0.2f')
plt.show()

# %% [markdown]
# # Outcome of correlation:

# %% [markdown]
# All the columns are positively correlated with the target column.
#
# TV has highest percent of correlation with target column 78 percent, followed by radio 58 percent and newspaper 23 percent.
#
# Max correlation: TV
#
# Min correlation: newspaper

# %% [markdown]
# # Describing datasets with heatmap:

# %%
sales.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(sales.describe().transpose(),annot=True,fmt='0.2f',linewidth=0.2,cmap='Blues_r',linecolor='black')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Variable Summary',fontsize=15)
plt.show()

# %% [markdown]
# # Outcome of describe of datasets:

# %% [markdown]
# From above we are determining mean, standard deviation, min. and max. value of each column, which will furthur help in data cleaning.

# %% [markdown]
# Total number of rows and columns in dataset:
#
#     1.200 rows
#     2.4 columns

# %% [markdown]
# TV:
#
#     1.Mean=147.04
#     2.std.=85.85
#     3.max_value=296.40
#     4.min_value=0.70
#
# radio:
#
#     1.Mean=23.26
#     2.std.=14.85
#     3.max_value=49.60
#     4.min_value=0.00
#
# newspaper:
#
#     1.Mean=30.55
#     2.std.=21.78
#     3.max_value=114.00
#     4.min_value=0.30
#
# sales:
#
#     1.Mean=14.02
#     2.std.=5.22
#     3.max_value=27.00
#     4.min_value=1.60
#
# sales is our target column.

# %% [markdown]
# # Using subplot and distplot to check data are normalised or not, considering mean values.

# %%
import itertools

cols=['TV',
     'radio',
     'newspaper']
length=len(cols)
cs=['b','r','g']
fig=plt.figure(figsize=(15,25))
for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(3,1,j+1)
    ax=sns.distplot(sales[i],color=k,rug=True)
    ax.set_facecolor('w')
    plt.axvline(sales[i].mean(),linestyle='--',label='mean',color='k')
    plt.legend(loc='best')
    plt.title(i,color='navy')
    plt.xlabel('')

# %% [markdown]
# # Observation:

# %% [markdown]
# From above we can see that data is normalised for features and we can proceed with data cleaning.

# %%
sales.hist(edgecolor='black',linewidth=2,figsize=(15,12))
# Out:
# array([[<AxesSubplot:title={'center':'TV'}>,
#         <AxesSubplot:title={'center':'radio'}>],
#        [<AxesSubplot:title={'center':'newspaper'}>,
#         <AxesSubplot:title={'center':'sales'}>]], dtype=object)

# %%
plt.figure(figsize=(10,8))
sales.corr()['sales'].sort_values(ascending=False).drop(['sales']).plot(kind='bar',color='teal')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Correlation with target column',fontsize=14)
plt.title('Correlation of features with the target column',fontsize=12)
plt.show()

# %% [markdown]
# None of the feature is having negative correlation.

# %%
sales.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
sales.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %% [markdown]
# # Skewness:

# %% [markdown]
# We are taking Skewness threshold as +/-0.5. From above, columns which fall under skewness:
#
#     newspaper, skewness=0.894720

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# From above we can have columns datatype and memory used by the dataframe.

# %% [markdown]
# # Outliers Checking:

# %% [markdown]
# To check outliers we are using boxplot.

# %%
sales.plot(kind='box',subplots=True,layout=(2,2),figsize=(16,20),color='green')
plt.xticks(fontsize=16)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# From above newspaper is having slight outliers.

# %% [markdown]
# # Removing outliers:

# %% [markdown]
# Checking the percentage of data falling under outliers.

# %%
from scipy.stats import zscore
import numpy as np

# %%
z=np.abs(zscore(sales))
z.shape
# Out:
# (200, 4)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 16, 101], dtype=int64), array([2, 2], dtype=int64))

# %%
sales_new=sales[(z<3).all(axis=1)]
print(sales.shape)
print(sales_new.shape)
# Out:
# (200, 4)
# (198, 4)

# %% [markdown]
# # Percentage data loss

# %%
loss_percent=(200-198)/200*100
print(loss_percent)
# Out:
# 1.0

# %% [markdown]
# Percentage loss is not more than 5 percent.

# %% [markdown]
# # Dividing data in features and vectors:

# %%
x=sales_new.drop(columns=['sales'])
y=sales_new['sales']

# %%
x.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# dtype: object

# %% [markdown]
# Observing relationship between features and target vectors:

# %%
plt.figure(figsize=(6,15),facecolor='white')
plotnumber=1

for column in x:
    if plotnumber<=5:
        ax=plt.subplot(3,1,plotnumber)
        sns.scatterplot(y,x[column])
        plt.xlabel('sales',fontsize=20)
        plt.ylabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Transforming data to remove skewness:

# %%
sales_new.skew()
# Out:
# TV          -0.082332
# radio        0.114842
# newspaper    0.650112
# sales        0.407130
# dtype: float64

# %% [markdown]
# Using power_transform to remove skewness:

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 0.95598306,  0.9691098 ,  1.6041965 ],
#        [-1.19200349,  1.04623436,  0.83104401],
#        [-1.6461253 ,  1.37296802,  1.60705249],
#        [ 0.14293428,  1.1473316 ,  1.28376774],
#        [ 0.45645241, -0.73502642,  1.28062154],
#        [-1.8204008 ,  1.51543955,  1.76610727],
#        [-1.00349358,  0.70309642, -0.10205346],
#        [-0.20996049, -0.0876566 , -0.84968895],
#        [-1.82264543, -1.62948287, -2.09866461],
#        [ 0.652694  , -1.56152179, -0.22649933],
#        [-0.88482761, -1.19258569, -0.06553382],
#        [ 0.80322028,  0.19357553, -1.59608414],
#        [-1.52567125,  0.82725998,  1.50859232],
#        [-0.48090308, -1.01613619, -1.23269654],
#        [ 0.69642374,  0.70856268,  0.86367455],
#        [ 0.60769456,  1.45886692,  1.1026083 ],
#        [ 1.44702338,  1.06152278,  1.19771741],
#        [-0.84304109, -0.02834315, -0.39458775],
#        [ 0.09676151,  0.18741189, -0.346834  ],
#        [ 0.84017479,  0.41523303,  1.11921444],
# ...

# %% [markdown]
# Applying Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_t=sc.fit_transform(x)
x_t
# Out:
# array([[ 0.95598306,  0.9691098 ,  1.6041965 ],
#        [-1.19200349,  1.04623436,  0.83104401],
#        [-1.6461253 ,  1.37296802,  1.60705249],
#        [ 0.14293428,  1.1473316 ,  1.28376774],
#        [ 0.45645241, -0.73502642,  1.28062154],
#        [-1.8204008 ,  1.51543955,  1.76610727],
#        [-1.00349358,  0.70309642, -0.10205346],
#        [-0.20996049, -0.0876566 , -0.84968895],
#        [-1.82264543, -1.62948287, -2.09866461],
#        [ 0.652694  , -1.56152179, -0.22649933],
#        [-0.88482761, -1.19258569, -0.06553382],
#        [ 0.80322028,  0.19357553, -1.59608414],
#        [-1.52567125,  0.82725998,  1.50859232],
#        [-0.48090308, -1.01613619, -1.23269654],
#        [ 0.69642374,  0.70856268,  0.86367455],
#        [ 0.60769456,  1.45886692,  1.1026083 ],
#        [ 1.44702338,  1.06152278,  1.19771741],
#        [-0.84304109, -0.02834315, -0.39458775],
#        [ 0.09676151,  0.18741189, -0.346834  ],
#        [ 0.84017479,  0.41523303,  1.11921444],
# ...

# %%
y.value_counts()
# Out:
# 9.7     5
# 15.9    4
# 11.7    4
# 12.9    4
# 20.7    3
#        ..
# 21.7    1
# 14.5    1
# 21.2    1
# 22.1    1
# 20.8    1
# Name: sales, Length: 121, dtype: int64

# %%
print(x_t.shape)
print(y.shape)
# Out:
# (198, 3)
# (198,)

# %% [markdown]
# # Regressor Model Building:

# %% [markdown]
# # Linear Regression:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lr=LinearRegression()
max_scr=0
for i in range(0,10000):
    x_train,x_test,y_train,y_test=train_test_split(x_t,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print('At random state',i,'The model performs well')
        print('At random state:-',i)
        print('Training score is:-',r2_score(y_train,pred_train)*100)
        print('Testing score is:-',r2_score(y_test,pred_test)*100)
# Out:
# At random state 112 The model performs well
# At random state:- 112
# Training score is:- 90.17428654220274
# Testing score is:- 90.16708364952682
# At random state 510 The model performs well
# At random state:- 510
# Training score is:- 90.41100608643733
# Testing score is:- 90.41484328551749
# At random state 1969 The model performs well
# At random state:- 1969
# Training score is:- 90.39700550120469
# Testing score is:- 90.39756491727574
# At random state 2938 The model performs well
# At random state:- 2938
# Training score is:- 90.44564395273248
# Testing score is:- 90.448505053535
# At random state 3604 The model performs well
# At random state:- 3604
# Training score is:- 90.44169188729934
# Testing score is:- 90.44426812151698
# At random state 5011 The model performs well
# At random state:- 5011
# Training score is:- 90.44139058537625
# Testing score is:- 90.43777523586301
# At random state 5601 The model performs well
# At random state:- 5601
# ...

# %%
x_train_b,x_test_b,y_train_b,y_test_b=train_test_split(x_t,y,random_state=5601,test_size=0.20)

# %% [markdown]
# We are using random state 9884, as at random state 5601, it is giving highest accuracy.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Regularization

# %% [markdown]
# # 1.Lasso:

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
grid_search=GridSearchCV(ls,parameters)
grid_search.fit(x_train,y_train)
print(grid_search.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train_b,y_train_b)
ls.score(x_train_b,y_train_b)
pred_ls=ls.predict(x_test_b)

lss=r2_score(y_test_b,pred_ls)
for i in range(2,10):
    lsscore=cross_val_score(ls,x_t,y,cv=i)
    lsc=lsscore.mean()
    print('At cv:-',i)
    print('cross validation score is:-',lsc*100)
    print('r2_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 2
# cross validation score is:- 90.14616379006017
# r2_score is:- 90.42326218062404
#
#
# At cv:- 3
# cross validation score is:- 89.72351383573026
# r2_score is:- 90.42326218062404
#
#
# At cv:- 4
# cross validation score is:- 89.80785666814384
# r2_score is:- 90.42326218062404
#
#
# At cv:- 5
# cross validation score is:- 89.57805874289184
# r2_score is:- 90.42326218062404
#
#
# At cv:- 6
# cross validation score is:- 89.81682352909685
# r2_score is:- 90.42326218062404
#
#
# At cv:- 7
# cross validation score is:- 89.46701250358076
# r2_score is:- 90.42326218062404
#
#
# At cv:- 8
# cross validation score is:- 89.81744733610321
# r2_score is:- 90.42326218062404
#
#
# At cv:- 9
# cross validation score is:- 89.36472532637083
# r2_score is:- 90.42326218062404

# %%
print('At cv:-',2)
print('cross validation score is:-',90.14616)
print('r2_score is:-',90.42326)
# Out:
# At cv:- 2
# cross validation score is:- 90.14616
# r2_score is:- 90.42326

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_ls))
print('mean squared error:',mean_squared_error(y_test_b,pred_ls))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_ls)))
# Out:
# Error
# mean absolute error: 1.227756611683374
# mean squared error: 2.3855558140687334
# root mean squared error: 1.5445244621140624

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_ls,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual sales',fontsize=14)
plt.ylabel('predicted sales',fontsize=14)
plt.title('Lasso Regression',fontsize=14)
plt.show()

# %% [markdown]
# # 2.Ridge:

# %%
from sklearn.linear_model import Ridge
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'fit_intercept':[True,False],'normalize':[True,False],'copy_X':[True,False],'tol':[0.001,0.01,0.1],'random_state':list(range(0,10))}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train_b,y_train_b)
print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'copy_X': True, 'fit_intercept': True, 'normalize': True, 'random_state': 0, 'tol': 0.001}

# %%
rd=Ridge(alpha=0.01,copy_X=True,fit_intercept=True,normalize=True,random_state=0,tol=0.001)
rd.fit(x_train_b,y_train_b)
pred_rd=rd.predict(x_test_b)
rds=r2_score(y_test_b,pred_rd)
print('r2 score is:',rds*100)
rdscore=cross_val_score(rd,x_t,y,cv=2)
rdc=rdscore.mean()
print('cross validation score is:',rdc*100)
# Out:
# r2 score is: 90.49786717181793
# cross validation score is: 90.15897912499331

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_rd))
print('mean squared error:',mean_squared_error(y_test_b,pred_rd))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_rd)))
# Out:
# Error
# mean absolute error: 1.2158063705301818
# mean squared error: 2.3669717853673276
# root mean squared error: 1.5384965990756456

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_rd,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual sales',fontsize=14)
plt.ylabel('predicted sales',fontsize=14)
plt.title('Ridge Regression',fontsize=14)
plt.show()

# %% [markdown]
# # Ensemble Techniques:

# %%
from sklearn.tree import DecisionTreeRegressor
parameters={'criterion':['mse','friedman_mse','mae'],'splitter':['best','random'],}
dtr=DecisionTreeRegressor()
clf=GridSearchCV(dtr,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'splitter': 'random'}

# %%
dtr=DecisionTreeRegressor(criterion='mae',splitter='random')
dtr.fit(x_train_b,y_train_b)
dtr.score(x_train_b,y_train_b)
pred_dtr=dtr.predict(x_test_b)
dts=r2_score(y_test_b,pred_dtr)
print('r2_score is:',dts*100)

dtscore=cross_val_score(dtr,x_t,y,cv=2)
dtc=dtscore.mean()
print('cross validation score is:',dtc*100)
# Out:
# r2_score is: 95.06822588609349
# cross validation score is: 90.33512405756167

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_dtr))
print('mean squared error:',mean_squared_error(y_test_b,pred_dtr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_dtr)))
# Out:
# Error
# mean absolute error: 0.875
# mean squared error: 1.2285
# root mean squared error: 1.10837719211467

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_dtr,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual sales',fontsize=14)
plt.ylabel('predicted sales',fontsize=14)
plt.title('Decision Tree Regressor',fontsize=14)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['friedman_mse','mae'],'n_estimators':[100,200,300]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'n_estimators': 100}

# %%
rf=RandomForestRegressor(criterion='mae',n_estimators=100)
rf.fit(x_train_b,y_train_b)
rf.score(x_train_b,y_train_b)
pred_rf=rf.predict(x_test_b)
rfs=r2_score(y_test_b,pred_rf)
print('r2_score is:',rfs*100)

rfscore=cross_val_score(rf,x_t,y,cv=2)
rfc=rfscore.mean()
print('cross validation score is:',rfc*100)
# Out:
# r2_score is: 98.58027019377838
# cross validation score is: 97.11387339675458

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_rf))
print('mean squared error:',mean_squared_error(y_test_b,pred_rf))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_rf)))
# Out:
# Error
# mean absolute error: 0.47747499999999976
# mean squared error: 0.3536532750000003
# root mean squared error: 0.5946875440094574

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_rf,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual sales',fontsize=14)
plt.ylabel('predicted sales',fontsize=14)
plt.title('Random Forest Regressor',fontsize=14)
plt.show()

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
parameters = {'loss' : ['ls', 'lad', 'huber', 'quantile'],'n_estimators':[50,100,200],'criterion':['friedman_mse', 'mse']}
gbr=GradientBoostingRegressor()
clf = GridSearchCV(gbr,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'loss': 'ls', 'n_estimators': 200}

# %%
gbr=GradientBoostingRegressor(criterion='friedman_mse',loss='ls',n_estimators=200)
gbr.fit(x_train_b,y_train_b)
gbr.score(x_train_b,y_train_b)
pred_gbr=gbr.predict(x_test_b)
gbrs=r2_score(y_test_b,pred_gbr)
print('r2_score is:',gbrs*100)

gbrscore=cross_val_score(gbr,x_t,y,cv=2)
gbrc=rfscore.mean()
print('cross validation score is:',gbrc*100)
# Out:
# r2_score is: 99.14408879802653
# cross validation score is: 97.11387339675458

# %%
print('Error')
print('mean absolute error:',mean_absolute_error(y_test_b,pred_gbr))
print('mean squared error:',mean_squared_error(y_test_b,pred_gbr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test_b,pred_gbr)))
# Out:
# Error
# mean absolute error: 0.3611319175412818
# mean squared error: 0.21320662450039057
# root mean squared error: 0.4617430286429786

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_gbr,color='b')
plt.plot(y_test_b,y_test_b,color='r')
plt.xlabel('actual sales',fontsize=14)
plt.ylabel('predicted sales',fontsize=14)
plt.title('Gradient Boost Regressor',fontsize=14)
plt.show()

# %%
from sklearn.svm import SVR

parameters = { 'kernel': ['linear', 'poly','rbf', 'sigmoid'],'gamma':['auto','scale']}
sv = SVR()
clf = GridSearchCV(sv,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'gamma': 'auto', 'kernel': 'rbf'}

# %%
sv = SVR(kernel = 'rbf', gamma = 'auto')
sv.fit(x_train_b, y_train_b)
sv.score(x_train_b, y_train_b)
pred_sv = sv.predict(x_test_b)

svs = r2_score(y_test_b,pred_sv)
print('R2 Score:',svs*100)

svscore = cross_val_score(sv,x_t,y,cv=2)
svc = svscore.mean() 
print('Cross Val Score:',svc*100)
# Out:
# R2 Score: 92.93495866470927
# Cross Val Score: 86.7087205934325

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b, y=pred_sv, color='b')
plt.plot(y_test_b,y_test_b, color='r')
plt.xlabel('Actual sales',fontsize=14)
plt.ylabel('Predicted sales',fontsize=14)
plt.title('Support vector regressor',fontsize=18)
plt.show()

# %% [markdown]
# # The best model is RandomForestRegressor.Since the difference between the percentage score of cross validation and r2_score is optimum.

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename='inhouse_advertising sales_project.pk6'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(rf.predict(x_test_b))
sales_com=pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
sales_com
# Out:
#     original  predicted
# 0       14.9     10.275
# 1       11.5     10.214
# 2       10.3     14.467
# 3       19.6     11.249
# 4       11.9      8.558
# 5       21.2     20.777
# 6       12.9     15.445
# 7       11.0     11.699
# 8        9.5     11.368
# 9       11.9     18.030
# 10      14.6      9.578
# 11       8.8     15.468
# 12       4.8     22.052
# 13      18.0     11.154
# 14      26.2      9.925
# 15      12.8      9.093
# 16      22.6     24.514
# 17       8.8      7.949
# 18      11.7      7.062
# 19      10.4      7.293
# 20      15.5     24.199
# 21      20.1     18.359
# 22       7.2     20.061
# 23      13.6     21.798
# 24      19.8      5.131
# 25      13.2     15.220
# 26      12.0     15.339
# 27      15.7     14.153
# 28      12.7     10.537
# 29       7.0      9.518
# 30      11.5     14.923
# 31       9.7     11.494
# 32      13.4     15.392
# 33      11.0     11.930
# 34       6.6     15.622
# 35      10.1     16.010
# 36      23.2     12.268
# ...

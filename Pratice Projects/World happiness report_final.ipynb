# %% [markdown]
# # World Happines Record:

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# # Happines Scores are based on:

# %% [markdown]
# Happiness scores and rankings use data from the Gallup World Poll.These scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2016 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.

# %% [markdown]
# # What is Dystopia?

# %% [markdown]
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.

# %% [markdown]
# # What are the residuals?

# %% [markdown]
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average life evaluations. These residuals have an average value of approximately zero over the whole set of countries.

# %% [markdown]
# # What do the columns succeeding the Happiness Score(like Family, Generosity, etc.) describe?

# %% [markdown]
# The following columns:
#
#     1.GDP per Capita
#
#     2.Family
#
#     3.Life Expectancy
#
#     4.Freedom
#
#     5.Generosity
#
#     6.Trust Government Corruption
#
# all these describe the extent to which these factors contribute in evaluating the happiness in each country.

# %%
import pandas as pd

# %%
df=pd.read_csv('World Happiness Report.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # About the Columns:

# %% [markdown]
# 1.Happiness Rank:
#
# Happiness score is the addition of all the fators.
#
# 2.Standard Error:
#
# It is approximate standard deviation of a statistical sample population.
#
# 3.Economy(GDP per Captia):
#
# GDP per capita measures the sum of marketed goods and services produced within the national boundary, averaged across everyone who lives within this territory.
#
# 4.Family:
#
# Group of one or more parents, and their children living together as a unit.
#
# 5.Health(Life Expectancy):
#
# Healthy life expectancy is the average life in good health.
#
# 6.Freedom:
#
# The power or right to act, speak, or think as one wants.
#
# 7.Trust(Government Corruption):
#
# Corruption is defined as the abuse of entrusted power for private gain.
#
# 8.Generosity:
#
# The quality of being kind and generous.
#
# 9.Dystopia Residual:
#
# The Dystopia Residual is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# # As country and Region are object datatype, we will make country as index and drop region, as it will not affect our data.

# %%
df=df.set_index('Country')
df=df.drop(columns=['Region'])
df.head()
# Out:
#              Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland               1            7.587         0.03411
# Iceland                   2            7.561         0.04884
# Denmark                   3            7.527         0.03328
# Norway                    4            7.522         0.03880
# Canada                    5            7.427         0.03553
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
# Denmark                       1.32548  1.36058                   0.87464
# Norway                        1.45900  1.33095                   0.88521
# Canada                        1.32629  1.32261                   0.90563
#
#              Freedom  Trust (Government Corruption)  Generosity  \
# Country
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# Using distplot and scatter plot let's see how data is distributed and analyze the relationship.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Here we can see all the building blocks are properly distributed within the normalised curve, and there doesn't seem any skewness.

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='white',fmt='.2f')
plt.show()

# %% [markdown]
# # Outcome of Correlation:

# %% [markdown]
# All the columns are positively correlated wth the target column.
#
# Economy(GDP per Capita), Family and Health(Life Expectancy) has 78, 74 and 72 percent correlation with target column which can be considered as strong bond.Freedom, Trust(Government Corruption) and Dystopia Residual has 57, 40 and 53 percent correlation with target column which can be considered as good bond. Generosity as only 18 percent correlation with target column which can be weak bond. Standard error is having minus 18 percent correlation wtih target column and can be considered as it won't have much effect on the target column. Happiness rank has negative correlation with target column
#
# Max correlation: Economy(GDP per Capita)
#
# Min correlation: Happiness Rank

# %% [markdown]
# # Describing Datasets:

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.describe().transpose(),annot=True,fmt='0.2f',linewidth=0.1)
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('Variable summary')
plt.show()

# %% [markdown]
# # Outcome of describe of datasets:

# %% [markdown]
# From above we are determining mean, standard deviation, min. and max. value of each column which will furthur help in data cleaning.
#
# Total number and in datasets:
#
#     1. 158 rows
#     2. 10 columns
#
# Happiness Rank:
#
#     1.Mean=79.49
#     2.std=45.75
#     3.max_value=158.00
#     4.min_value=1.00
#
# Standard Eror:
#
#     1.Mean=0.05
#     2.std=0.02
#     3.max_value=0.14
#     4.min_value=0.02
#
# Economy (GDP per Capita):
#
#     1.Mean=0.85
#     2.std=0.40
#     3.max_value=1.69
#     4.min_value=0.00
#
# Family:
#
#     1.Mean=0.99
#     2.std=0.27
#     3.max_value=1.40
#     4.min_value=0.00
#
# Health (Life Expectancy):
#
#     1.Mean=0.63
#     2.std=0.25
#     3.max_value=1.03
#     4.min_value=0.00
#
# Freedom:
#
#     1.Mean=0.43
#     2.std=0.15
#     3.max_value=0.67
#     4.min_value=0.00
#
# Trust (Government Corruption):
#
#     1.Mean=0.14
#     2.std=0.12
#     3.max_value=0.55
#     4.min_value=0.00
#
# Generosity:
#
#     1.Mean=0.24
#     2.std=0.13
#     3.max_value=0.80
#     4.min_value=0.00
#
# Dystopia Residual:
#
#     1.Mean=2.10
#     2.std=0.55
#     3.max_value=3.60
#     4.min_value=0.33
#
# Happiness Score:
#
#     1.Mean=5.38
#     2.std=1.15
#     3.max_value=7.59
#     4.min_value=2.84
#
# Happiness Score is the target value.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, Switzerland to Togo
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Rank                 158 non-null    int64
#  1   Happiness Score                158 non-null    float64
#  2   Standard Error                 158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1)
# memory usage: 13.6+ KB

# %% [markdown]
# From above we can have columns datatype and memory used by the dataframe.

# %% [markdown]
# # Outliers Checking:

# %%
df.plot(kind='box',subplots=True,layout=(3,4),figsize=(16,20),color='green')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# From above we can see that columns['Happiness Rank','Economy (GDP per Capita)','Health (Life Expectancy)','Freedom'] have no outliers, columns ['Family', 'Generosity','Dystopia Residual'] has less outliers, while column 'Trust (Government Corruption)' has more outliers and our target column 'Happiness Score' have no outlires.

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Outcome of the skewness: Skewness threshold is +/-0.5. Columns which are having Skewness
#
#     Standard Error
#     Family
#     Health (Life Expectancy)
#     Trust (Government Corruption)
#     Generosity

# %% [markdown]
# # Normal Distribution Curve:

# %% [markdown]
# As seen earlier in EDA, distplot showed decent distribution of the building blocks within the curve

# %% [markdown]
# # Removing outliers:

# %% [markdown]
# Z-Score Technique:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 10)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (158, 10)
# (149, 10)

# %% [markdown]
# # Percentage Data Loss:

# %%
loss_percent=(158-149)/158*100
print(loss_percent)
# Out:
# 5.69620253164557

# %% [markdown]
# Checking whether how much outliers are still there. If the outliers there help in the testing the model or not.

# %% [markdown]
# # Model without outliers is df and model with desired outliers is df_new:

# %% [markdown]
# Moving our target column 'Happiness Score' in last.

# %%
last_column=df_new.pop('Happiness Score')
df_new.insert(9,'Happiness Score',last_column)
print()
display(df_new)
# Out:
#               Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# Country
# Switzerland                1         0.03411                   1.39651
# Iceland                    2         0.04884                   1.30232
# Denmark                    3         0.03328                   1.32548
# Norway                     4         0.03880                   1.45900
# Canada                     5         0.03553                   1.32629
# ...                      ...             ...                       ...
# Ivory Coast              151         0.05141                   0.46534
# Burkina Faso             152         0.04324                   0.25812
# Afghanistan              153         0.03084                   0.31982
# Benin                    155         0.03656                   0.28665
# Burundi                  157         0.08658                   0.01530
#
#                Family  Health (Life Expectancy)  Freedom  \
# Country
# ...

# %% [markdown]
# Dividing data in features and vectors:

# %%
x=df_new.drop(columns=['Happiness Score'])
y=df_new['Happiness Score']

# %%
x.dtypes
# Out:
# Happiness Rank                     int64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# Observing relationship between features and tagert vectors.

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in x:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Happiness Score',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Here we can see, as the happiness score goes down rank also goes down.
#
# Standard error has not much effect, it lies between the range (0.03-0.06).
#
# Economy, Family, Health, Freedom, Dystopia Residual, have impact on happiness score, as these increases, Happiness rank also increases.
#
# Trust and generosity has less impact, as trust goes down, happiness score goes down and same with the generosity. Trust and generosity are in the range (0-0.03)max., (0.00-0.03)max.

# %% [markdown]
# # Transforming data to remove skewness:

# %%
df_new.skew()
# Out:
# Happiness Rank                   0.003268
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# Happiness Score                  0.169740
# dtype: float64

# %% [markdown]
# Outcome of Skewness:
#     the normal skewness outcome is between +/-0.5.
#
# Columns which are not under the normal skewness range:
#
#     Standard Error
#     Family
#     Health (Life Expectancy)
#     Trust (Government Corruption)
#     Generosity

# %% [markdown]
# Using power_transform to remove skewness.

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-2.05151352, -0.95033703,  1.49245411, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [-1.99584442,  0.37856182,  1.19406711, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-1.94524081, -1.04140135,  1.26661161, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [ 1.53128908, -1.32081011, -1.36521585, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [ 1.56626337, -0.69272644, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 1.60111233,  2.17876604, -1.93874732, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %% [markdown]
# Applying Standard Scaler.

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-2.05151352, -0.95033703,  1.49245411, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [-1.99584442,  0.37856182,  1.19406711, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-1.94524081, -1.04140135,  1.26661161, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [ 1.53128908, -1.32081011, -1.36521585, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [ 1.56626337, -0.69272644, -1.43304072, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 1.60111233,  2.17876604, -1.93874732, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %% [markdown]
# # Since the outcome is Continuous values we will use Linear Regression on model.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import accuracy_score

# %%
print(x.shape)
print(y.shape)
# Out:
# (149, 9)
# (149,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=355,test_size=0.25)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-0.31422292,  0.00273856,  0.27616112,  0.18276386,  0.18610917,
#         0.11016114,  0.0514707 ,  0.06913031,  0.36786423])

# %%
lr.intercept_
# Out:
# 5.428512945004716

# %%
lr.score(x_train,y_train)
# Out:
# 0.9951624742575547

# %%
lr.score(x_test,y_test)
# Out:
# 0.9963996510436303

# %% [markdown]
# Here we can see, Train and test score for linear regression are almost equal.

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9963996510436303

# %%
scores=cross_val_score(lr,x,y,scoring='r2',cv=5)
scr4=scores

# %%
scr4.mean()
# Out:
# 0.843270186810454

# %% [markdown]
# Here the acutal and predicted score is almost equal. Hence model is performing well.

# %%
#predict the value
print('Predicted Happiness Score',y_pred)
print('Actual Happiness Score',y_test)
# Out:
# Predicted Happiness Score [3.84380131 5.72058766 5.76382295 5.3382632  5.15021733 4.41090157
#  5.45361242 3.88710936 4.17975796 4.5933787  5.68475573 3.95694822
#  4.4247285  6.36091959 6.99896863 6.47974812 6.80390575 7.50509174
#  4.91182637 3.75624016 6.2262996  6.68281521 6.59354232 5.50723678
#  6.7587865  3.77678339 4.48578877 3.71565783 6.48921902 5.49798953
#  6.34990259 4.06430084 7.72752874 6.08593704 4.41185845 5.41945676
#  4.56549694 5.96124323]
# Actual Happiness Score Country
# Cambodia                  3.819
# Malaysia                  5.770
# Peru                      5.824
# Vietnam                   5.360
# Jordan                    5.192
# Malawi                    4.292
# Turkmenistan              5.548
# Senegal                   3.904
# Bulgaria                  4.218
# Congo (Kinshasa)          4.517
# Cyprus                    5.689
# Comoros                   3.956
# Haiti                     4.518
# Thailand                  6.455
# ...

# %% [markdown]
# # Error Checkings:

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
print('Error!')
print('Mean absolute error:',mean_absolute_error(y_test,y_pred))
print('Mean squared error:',mean_squared_error(y_test,y_pred))
# Out:
# Error!
# Mean absolute error: 0.054016646218558555
# Mean squared error: 0.004590422639095585

# %% [markdown]
# # Applying Regularization:

# %%
from sklearn.linear_model import Lasso,LassoCV,Ridge,RidgeCV

# %% [markdown]
# # Using Lasso Regression:

# %%
lasscv=LassoCV(alphas=None,cv=10,max_iter=1000,normalize=True)
lasscv.fit(x_train,y_train)
# Out:
# LassoCV(cv=10, normalize=True)

# %% [markdown]
# finding the best alpha parameter.

# %%
alpha=lasscv.alpha_
alpha
# Out:
# 0.00010389709789890849

# %% [markdown]
# we got our best alpha parameter, using this, we will find lasso regression.

# %%
lasso_reg=Lasso(alpha)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.00010389709789890849)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.9964494485727226

# %%
scores=cross_val_score(lasscv,x,y,scoring='r2',cv=5)
scr3=scores

# %%
scr3.mean()
# Out:
# 0.8397686664163817

# %% [markdown]
# # Using Ridge Regression:

# %%
alphas=np.random.uniform(low=0,high=10,size=(50))
ridgecv=RidgeCV(alphas=alphas,cv=10,normalize=True)
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([2.17851002, 9.75898507, 4.02789159, 3.35827191, 9.11106835,
#        0.52025764, 8.95016265, 5.89039958, 0.39854462, 9.96493439,
#        8.69748035, 3.6447152 , 3.95606278, 5.63211378, 4.75332006,
#        2.21238872, 6.14453449, 5.82748071, 6.04929457, 0.27647129,
#        4.85813782, 9.35304746, 4.87692724, 9.44514795, 7.21464226,
#        3.19327101, 1.26420644, 3.2617603 , 2.62476885, 1.97974021,
#        0.50416273, 7.83079034, 8.31254154, 8.45764744, 6.6755142 ,
#        8.05463624, 2.35596428, 2.30275953, 5.60164692, 4.83984957,
#        6.30009366, 6.87669327, 0.57009253, 7.58479423, 2.48676667,
#        0.52955284, 6.72764242, 3.96853289, 1.77309934, 2.25787071]),
#         cv=10, normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.27647129180485064

# %%
ridge_model=Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.27647129180485064)

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.9964519153674307

# %%
scores=cross_val_score(ridgecv,x,y,scoring='r2',cv=5)
scr2=scores

# %%
scr2.mean()
# Out:
# 0.6230408098843636

# %% [markdown]
# Here we can see, ridge score is =0.999828 and lasso score is =0.9999762
#
# So, Lasso is better than ridge.

# %% [markdown]
# # Applying SVR- Support Vector Regressor:

# %%
from sklearn.svm import SVR
svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

svr=SVR(kernel='poly')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

svr=SVR(kernel='rbf')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

# %%
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    sv.score(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.9947872834743198
# 0.9640300055116326
# 0.9845114268141697

# %%
scores=cross_val_score(sv,x_test,y_test,scoring='r2',cv=10)
scr=scores

# %%
scr.mean()
# Out:
# 0.7863382175504416

# %%
from sklearn.svm import SVR
svr1=SVR(kernel='linear')
svr1.fit(x_test,y_test)
svr1.score(x_test,y_test)
pred_y=svr1.predict(x_test)

svr1=SVR(kernel='poly')
svr1.fit(x_test,y_test)
svr1.score(x_test,y_test)
pred_y=svr1.predict(x_test)

svr1=SVR(kernel='rbf')
svr1.fit(x_test,y_test)
svr1.score(x_test,y_test)
pred_y=svr1.predict(x_test)

# %%
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv1=SVR(kernel=i)
    sv1.fit(x_test,y_test)
    sv1.score(x_test,y_test)
    print(sv1.score(x_test,y_test))
# Out:
# 0.9961665105109679
# 0.9609806798764533
# 0.9861568364037878

# %%
scores=cross_val_score(sv1,x,y,scoring='r2',cv=5)
scr1=scores

# %%
scr1.mean()
# Out:
# -3.3375790044030738

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename='inhouse_Happiness_report.pk1'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
df_com
# Out:
#     original  predicted
# 0      3.819   3.843801
# 1      5.770   5.720588
# 2      5.824   5.763823
# 3      5.360   5.338263
# 4      5.192   5.150217
# 5      4.292   4.410902
# 6      5.548   5.453612
# 7      3.904   3.887109
# 8      4.218   4.179758
# 9      4.517   4.593379
# 10     5.689   5.684756
# 11     3.956   3.956948
# 12     4.518   4.424729
# 13     6.455   6.360920
# 14     6.940   6.998969
# 15     6.329   6.479748
# 16     6.810   6.803906
# 17     7.527   7.505092
# 18     4.949   4.911826
# 19     3.667   3.756240
# 20     6.269   6.226300
# 21     6.575   6.682815
# 22     6.574   6.593542
# 23     5.474   5.507237
# 24     6.798   6.758786
# 25     3.781   3.776783
# 26     4.512   4.485789
# 27     3.655   3.715658
# 28     6.485   6.489219
# 29     5.589   5.497990
# 30     6.411   6.349903
# 31     4.033   4.064301
# 32     7.561   7.727529
# 33     6.123   6.085937
# 34     4.514   4.411858
# 35     5.477   5.419457
# 36     4.633   4.565497
# ...
